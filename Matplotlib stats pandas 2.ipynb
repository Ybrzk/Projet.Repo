# %%
import pandas

# %%
pandas.read_excel("/home/yacine/Téléchargements/autompg.xlsx",sep = '\t',header = 0)
# Out:
#       mpg  cylindres  déplacement  puissance  poids  accélération  \
# 0    18.0          8        307.0      130.0   3504          12.0
# 1    15.0          8        350.0      165.0   3693          11.5
# 2    18.0          8        318.0      150.0   3436          11.0
# 3    16.0          8        304.0      150.0   3433          12.0
# 4    17.0          8        302.0      140.0   3449          10.5
# ..    ...        ...          ...        ...    ...           ...
# 393  27.0          4        140.0       86.0   2790          15.6
# 394  44.0          4         97.0       52.0   2130          24.6
# 395  32.0          4        135.0       84.0   2295          11.6
# 396  28.0          4        120.0       79.0   2625          18.6
# 397  31.0          4        119.0       82.0   2720          19.4
#
#      année de modèle  origine          Nom de la voiture
# 0                 70        1  chevrolet chevelle malibu
# 1                 70        1          buick skylark 320
# ...

# %%
print(df.dtypes)
# Out:
# mpg                  float64
# cylindres              int64
# déplacement          float64
# puissance            float64
# poids                  int64
# accélération         float64
# année de modèle        int64
# origine                int64
# Nom de la voiture     object
# dtype: object

# %%
import matplotlib.pyplot as plt

# %%
df.hist(column='puissance')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f22970f8410>]],
#       dtype=object)

# %%
import pandas as pd
import matplotlib.pyplot as plt

liste=["mpg","cylindres","déplacement","puissance","poids","accélération","année de modèle","origine",
"nom de la voiture)"]

plt.figure(figsize=(10,10))
auto=pd.read_excel('/home/yacine/Téléchargements/autompg.xlsx', sep= '\t', names =liste)
auto['année de modèle'].value_counts().plot.pie()

# %%
auto.plot.scatter(x='puissance',y='tauxmax',s=auto['poids'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'tauxmax'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-f84db9eba0ff> in <module>
# ...
